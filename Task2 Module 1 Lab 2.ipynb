# %% [markdown]
# <a href="https://colab.research.google.com/github/Samarth1410/Samarth_FMML/blob/main/Task2%20Module%201%20Lab%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The Banknote Dataset involves predicting whether a given banknote is authentic given a number of measures taken from a photograph.
#
# It is a binary (2-class) classification problem. The number of observations for each class is not balanced. There are 1,372 observations with 4 input variables and 1 output variable. The variable names are as follows:
#
#     Variance of Wavelet Transformed image (continuous).
#     Skewness of Wavelet Transformed image (continuous).
#     Kurtosis of Wavelet Transformed image (continuous).
#     Entropy of image (continuous).
#     Class (0 for authentic, 1 for inauthentic).
#
# The baseline performance of predicting the most prevalent class is a classification accuracy of approximately 50%

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/IRIS.csv')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
sns.scatterplot(data = data ,y='sepal_length' , x = 'sepal_width' , hue='species')

# %%
sns.scatterplot(data = data ,y='petal_length' , x = 'sepal_width', hue='species')

# %% [markdown]
# Iris setosa has petal length less than 2.2  and sepal width greater than 3.

# %%
sns.violinplot(data = data, x='species', y ='petal_length')

# %%
sns.violinplot(data = data, x='species', y ='petal_width')

# %%
sns.violinplot(data = data, x='species', y ='sepal_length')

# %%
sns.violinplot(data = data, x='species', y ='sepal_width')

# %%
fig, axes = plt.subplots(2, 2)
sns.boxplot(data=data, x='species' , y='sepal_length', ax=axes[0,0],)
sns.boxplot(data=data, x='species' , y='sepal_width', ax=axes[0,1])
sns.boxplot(data=data, x='species' , y='petal_length', ax=axes[1,0])
sns.boxplot(data=data, x='species' , y='petal_width', ax=axes[1,1])

# %%
sns.pairplot(data=data, hue = 'species')

# %% [markdown]
# DATA INSIGHTS :
#
# In Iris-setosa : petal length = smallest and petal width = smallest and can be clearly seperable by this.
#
# Iris-versicolor and Iris-Virginica can be distinguished by Petal Width.
#
# Verginica has largest petal width and versicolor lies in between.
